# %% [markdown]
# <a href="https://colab.research.google.com/github/1970332/IAyRN/blob/main/Regresi%C3%B3n_Lineal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Actividad 2: Diseño de algoritmos en Python**
#
# Andy Alexander López Ovalle 1970332 Hora: N4 a N6

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Generar datos
np.random.seed(0)
horas_estudio = np.random.rand(100, 1) * 10
calificaciones = 2 * horas_estudio + np.random.randn(100,1) * 2

# Preprocesamiento de datos
train_data, test_data, train_labels, test_labels = train_test_split(horas_estudio, calificaciones, test_size=0.2, random_state=0)

# Selección y entrenamiento del modelo
model = LinearRegression()
model.fit(train_data, train_labels)

# Prueba del modelo
predicciones = model.predict(test_data)
mse = mean_squared_error(test_labels, predicciones)

# Graficar el modelo de regresión lineal
plt.scatter(test_data, test_labels, color='blue')
plt.plot(test_data, predicciones, color='red')
plt.title('Regresión Lineal')
plt.xlabel('Horas de estudio')
plt.ylabel('Calificaciones')
plt.show()

# Mostrar el error cuadrático medio
print("Error Cuadrático Medio:", mse)
# Out:
# Error Cuadrático Medio: 4.17373352627807
